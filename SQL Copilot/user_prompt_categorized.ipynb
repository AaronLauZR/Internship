# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Dan/categorized_expenses_desc.csv')

# %%
df
# Out:
#       Unnamed: 0     CODE       GL_DESCRIPTION  \
# 0              0  903-000        ENTERTAINMENT
# 1              1  903-000        ENTERTAINMENT
# 2              2  903-000        ENTERTAINMENT
# 3              3  903-000        ENTERTAINMENT
# 4              4  903-000        ENTERTAINMENT
# ...          ...      ...                  ...
# 2072        2072  968-000        HRDF EXPENSES
# 2073        2073  968-000        HRDF EXPENSES
# 2074        2074  968-000        HRDF EXPENSES
# 2075        2075  968-000        HRDF EXPENSES
# 2076        2076  989-000  LOSS IN COURTS CASE
#
#                                          CB_DESCRIPTION     FORMAT  \
# 0                                              - WREATH       What
# 1                            - FRIM & COWAY AUDIT LUNCH   Who-What
# 2                                         - COWAY LUNCH       What
# 3                                         - COWAY LUNCH       What
# ...

# %%
def find_matching_row(dataframe, **kwargs):
    print(kwargs)
    for index, row in dataframe.iterrows():
        match = all(kwargs[key] == str(row[key]) for key in kwargs)
        if match:
            return row

    return None

# Example usage
user_input_who = input("Enter Who: ")
user_input_what = input("Enter What: ")
user_input_why = input("Enter Why: ")
user_input_where = input("Enter Where: ")
user_input_when = input("Enter When: ")
matching_row = find_matching_row(df, Who=user_input_who, What=user_input_what)

if matching_row is not None:
    print("Matching row found:")
    print(matching_row)
else:
    print("No matching row found.")
# Out:
# Enter Who: FRIM & COWAY
# Enter What: AUDIT LUNCH
# Enter Why:
# Enter Where:
# Enter When:
# {'Who': 'FRIM & COWAY', 'What': 'AUDIT LUNCH'}
# Matching row found:
# Unnamed: 0                                  1
# CODE                                  903-000
# GL_DESCRIPTION                  ENTERTAINMENT
# CB_DESCRIPTION     - FRIM & COWAY AUDIT LUNCH
# FORMAT                               Who-What
# Who                              FRIM & COWAY
# What                              AUDIT LUNCH
# Why                                       NaN
# Where                                     NaN
# When                                      NaN
# Name: 1, dtype: object
